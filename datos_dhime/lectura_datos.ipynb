# %%
import pandas as pd

# %%
datos = pd.read_csv('Catálogo_Nacional_de_Estaciones_del_IDEAM_20260620.csv')
datos_Bogota = datos[datos['Departamento'].str.contains('Bogotá', case=False)]
datos_Bogota
# Out:
#           Codigo                                             Nombre  \
# 15      21205380                              HIPOTECHO  [21205380]
# 42    2120000122  COLEGIO INEM FRANCISCO DE PAULA SANTANDER (IED...
# 45      21200310                          CERRO DE SUBA  [21200310]
# 47      21206500                 COLEGIO ABRAHAM LINCOLN [21206500]
# 49    2120000169              COLEGIO LA BELLEZA (IED) [2120000169]
# ...          ...                                                ...
# 9303    21206730                              GIBRALTAR  [21206730]
# 9430    21207030                           DECANTADORES  [21207030]
# 9446    21201200                        ESCUELA LA UNION [21201200]
# 9454    21205012                    UNIVERSIDAD NACIONAL [21205012]
# 9474    21206690                  COLEGIO MIGUEL A. CARO [21206690]
#
#                     Categoria                 Tecnologia      Estado  \
# 15    Climatológica Ordinaria               Convencional      Activa
# ...

# %%
precipitacion = pd.read_csv('descargaDhime.csv')
precipitacion
# Out:
#    CodigoEstacion                       NombreEstacion       Variable  \
# 0        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 1        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 2        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 3        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 4        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 5        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
# 6        21202280  SEDE IDEAM CALLE 25D KRA [21202280]  PRECIPITACION
#
#                           Parametro             Fecha Unidad  Valor  \
# 0  Día pluviométrico (convencional)  2026-06-12 00:00     mm    0.0
# 1  Día pluviométrico (convencional)  2026-06-13 00:00     mm    0.0
# 2  Día pluviométrico (convencional)  2026-06-14 00:00     mm    1.9
# 3  Día pluviométrico (convencional)  2026-06-15 00:00     mm    1.9
# ...
